# %% [markdown]
# ![alt text](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTK4gQ9nhwHHaSXMHpeggWg7twwMCgb877smkRmtkmDeDoGF9Z6&usqp=CAU)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <font color = Blue>3 Principais componentes da IA

# %% [markdown]
# # LLM

# %% [markdown]
# https://artificialanalysis.ai/models
#
# https://artificialanalysis.ai/leaderboards/providers
#
# https://llmmodels.org/

# %% [markdown]
# #### Exemplos Práticos

# %% [markdown]
# Google Gemini

# %% [markdown]
# https://colab.research.google.com/drive/1q_Q7guNAWIJ94GZThC2orZ9PZkTJiYBl?usp=sharing

# %% [markdown]
# Meta LLama 3.3

# %% [markdown]
# https://colab.research.google.com/drive/1gkfZw0pRzYvU3efVS1rlfbr8CU3xItTw?usp=sharing

# %% [markdown]
# Anthropic Claude 3.5

# %% [markdown]
# https://colab.research.google.com/drive/1oDjXz68pqyx5UrCkkZrKKdGpaBAAOzpX?usp=sharing

# %% [markdown]
# Mistral Large

# %% [markdown]
# https://colab.research.google.com/drive/1KfcRtg6OVArsJ4_CvurS1OAfxmtyaTA_?usp=sharing

# %% [markdown]
# HugginFace

# %% [markdown]
# https://huggingface.co/spaces/gabrielchua/open-notebooklm

# %% [markdown]
# # RAG Systems

# %% [markdown]
# **Retrieval-Augmented Generation (RAG)**
#
# Principais aplicações dos sistemas RAG no local de trabalho
#
# * Gestão do Conhecimento e Recuperação de Informação
#
# * Suporte ao cliente e chatbots
#
# * Marketing de conteúdo
#
# * Sistemas de Apoio à Decisão
#
# * Integração e Treinamento de Funcionários
#
# * Pesquisa e Desenvolvimento (P&D)
#
# * Conformidade e documentação legal (LexAI)
#
# * Ferramentas e recursos educacionais

# %% [markdown]
# https://notebooklm.google.com/

# %% [markdown]
# #Agents AI

# %% [markdown]
# https://aiagentsdirectory.com/

# %% [markdown]
# # Principais Frameworks de Agents AI

# %% [markdown]
# https://github.com/langchain-ai/langgraph

# %% [markdown]
# https://github.com/crewAIInc/crewAI

# %% [markdown]
# https://github.com/kyegomez/swarms

# %% [markdown]
# https://github.com/MervinPraison/PraisonAI

# %% [markdown]
# https://github.com/composiohq

# %% [markdown]
# https://github.com/agno-agi/agno

# %% [markdown]
# # API Tools

# %% [markdown]
# https://colab.research.google.com/drive/1T7pOYwMFt7opI8Z-yEXeSnAprpgFbEXL?usp=sharing

# %% [markdown]
# ## <Font color = blue> Case FullStack

# %% [markdown]
# https://github.com/agno-agi/agno

# %% [markdown]
# #FIM

# %% [markdown]
# ##<font color= Brawn>Scripts e Anexos
# https://linktr.ee/cienciadosdados
